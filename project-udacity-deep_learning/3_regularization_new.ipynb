# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# 采用logistic模型测试，不同的L2 regularization下分类效果的不同，采用的拟合batch size的大小为 128.
#
# ---

# %%
beta_val = np.logspace(-4, -2, 20)
batch_size = 128
accuracy_val = []

graph = tf.Graph()
with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32,
                                      shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights = tf.Variable(tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  beta_regul = tf.placeholder(tf.float32)
    
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels)) + beta_regul * tf.nn.l2_loss(weights)  
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
num_steps = 3001

for beta in beta_val:
    with tf.Session(graph=graph) as session:
        #tf.initialize_all_variables().run()
        tf.global_variables_initializer().run
        for step in range(num_steps):
            # offset 
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            # Prepare a dictionary telling the session where to feed the minibatch.
            feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels, beta_regul: beta}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 500 == 0):
                print("Minibatch loss at step %d: %f" % (step, l))
                print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
                print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
        print("L2 regularization(beta=%.5f) Test accuracy: %.1f%%" % (beta, accuracy(test_prediction.eval(), test_labels)))

        accuracy_val.append(accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 18.215281
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.6%
# Minibatch loss at step 500: 1.190510
# Minibatch accuracy: 82.0%
# Validation accuracy: 75.6%
# Minibatch loss at step 1000: 1.480732
# Minibatch accuracy: 76.6%
# Validation accuracy: 77.2%
# Minibatch loss at step 1500: 0.941327
# Minibatch accuracy: 82.0%
# Validation accuracy: 77.6%
# Minibatch loss at step 2000: 0.857946
# Minibatch accuracy: 82.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 2500: 1.034810
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 3000: 1.112719
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.2%
# L2 regularization(beta=0.00010) Test accuracy: 86.6%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 19.517357
# Minibatch accuracy: 7.8%
# Validation accuracy: 8.6%
# Minibatch loss at step 500: 1.244856
# Minibatch accuracy: 82.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 1000: 1.687153
# Minibatch accuracy: 78.1%
# Validation accuracy: 76.7%
# Minibatch loss at step 1500: 0.974272
# Minibatch accuracy: 79.7%
# Validation accuracy: 77.3%
# Minibatch loss at step 2000: 0.985191
# Minibatch accuracy: 82.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 2500: 0.945136
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.2%
# Minibatch loss at step 3000: 1.016103
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.7%
# L2 regularization(beta=0.00013) Test accuracy: 87.1%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 19.259319
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.2%
# Minibatch loss at step 500: 1.382511
# Minibatch accuracy: 83.6%
# Validation accuracy: 75.1%
# Minibatch loss at step 1000: 1.458532
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.5%
# Minibatch loss at step 1500: 0.998354
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 2000: 1.049816
# Minibatch accuracy: 83.6%
# Validation accuracy: 77.9%
# Minibatch loss at step 2500: 1.169239
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 3000: 1.115628
# Minibatch accuracy: 78.9%
# Validation accuracy: 79.5%
# L2 regularization(beta=0.00016) Test accuracy: 86.9%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 21.845730
# Minibatch accuracy: 8.6%
# Validation accuracy: 10.2%
# Minibatch loss at step 500: 1.653201
# Minibatch accuracy: 79.7%
# Validation accuracy: 75.5%
# Minibatch loss at step 1000: 1.659785
# Minibatch accuracy: 75.8%
# Validation accuracy: 76.4%
# Minibatch loss at step 1500: 1.182961
# Minibatch accuracy: 82.8%
# Validation accuracy: 77.4%
# Minibatch loss at step 2000: 0.934504
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 2500: 1.115453
# Minibatch accuracy: 75.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 3000: 0.983833
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.8%
# L2 regularization(beta=0.00021) Test accuracy: 87.6%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 19.710520
# Minibatch accuracy: 5.5%
# Validation accuracy: 9.7%
# Minibatch loss at step 500: 1.628860
# Minibatch accuracy: 78.9%
# Validation accuracy: 75.8%
# Minibatch loss at step 1000: 1.660219
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.1%
# Minibatch loss at step 1500: 1.027708
# Minibatch accuracy: 83.6%
# Validation accuracy: 78.1%
# Minibatch loss at step 2000: 0.994831
# Minibatch accuracy: 86.7%
# Validation accuracy: 79.0%
# Minibatch loss at step 2500: 1.079312
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.5%
# Minibatch loss at step 3000: 0.942118
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# L2 regularization(beta=0.00026) Test accuracy: 87.5%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 18.633348
# Minibatch accuracy: 9.4%
# Validation accuracy: 10.2%
# Minibatch loss at step 500: 2.111421
# Minibatch accuracy: 76.6%
# Validation accuracy: 75.6%
# Minibatch loss at step 1000: 1.556010
# Minibatch accuracy: 80.5%
# Validation accuracy: 77.3%
# Minibatch loss at step 1500: 0.992826
# Minibatch accuracy: 85.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 2000: 1.054016
# Minibatch accuracy: 85.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 2500: 1.075821
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.5%
# Minibatch loss at step 3000: 0.972132
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.5%
# L2 regularization(beta=0.00034) Test accuracy: 88.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 18.141294
# Minibatch accuracy: 11.7%
# Validation accuracy: 14.0%
# Minibatch loss at step 500: 1.940481
# Minibatch accuracy: 79.7%
# Validation accuracy: 75.5%
# Minibatch loss at step 1000: 1.714328
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 1500: 1.079871
# Minibatch accuracy: 82.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 2000: 1.005646
# Minibatch accuracy: 85.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 2500: 1.057585
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.2%
# Minibatch loss at step 3000: 0.931996
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.9%
# L2 regularization(beta=0.00043) Test accuracy: 88.1%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 21.483593
# Minibatch accuracy: 8.6%
# Validation accuracy: 12.3%
# Minibatch loss at step 500: 1.972514
# Minibatch accuracy: 82.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 1000: 1.987789
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.2%
# Minibatch loss at step 1500: 1.005378
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 2000: 0.994890
# Minibatch accuracy: 86.7%
# Validation accuracy: 79.6%
# Minibatch loss at step 2500: 0.977706
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 0.934982
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.7%
# L2 regularization(beta=0.00055) Test accuracy: 88.6%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 17.531677
# Minibatch accuracy: 10.2%
# Validation accuracy: 14.5%
# Minibatch loss at step 500: 2.183478
# Minibatch accuracy: 79.7%
# Validation accuracy: 76.0%
# Minibatch loss at step 1000: 1.893291
# Minibatch accuracy: 80.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 1500: 1.051791
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.2%
# Minibatch loss at step 2000: 0.959995
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.8%
# Minibatch loss at step 2500: 0.902644
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.9%
# Minibatch loss at step 3000: 0.775875
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.6%
# L2 regularization(beta=0.00070) Test accuracy: 88.5%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 18.649591
# Minibatch accuracy: 12.5%
# Validation accuracy: 13.7%
# Minibatch loss at step 500: 2.281757
# Minibatch accuracy: 76.6%
# Validation accuracy: 75.8%
# Minibatch loss at step 1000: 1.698580
# Minibatch accuracy: 79.7%
# Validation accuracy: 78.1%
# Minibatch loss at step 1500: 1.002276
# Minibatch accuracy: 85.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 2000: 0.834400
# Minibatch accuracy: 86.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 2500: 0.872451
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.5%
# Minibatch loss at step 3000: 0.800189
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# L2 regularization(beta=0.00089) Test accuracy: 89.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 17.208258
# Minibatch accuracy: 14.8%
# Validation accuracy: 14.1%
# Minibatch loss at step 500: 2.557533
# Minibatch accuracy: 80.5%
# Validation accuracy: 76.4%
# Minibatch loss at step 1000: 1.759090
# Minibatch accuracy: 77.3%
# Validation accuracy: 79.1%
# Minibatch loss at step 1500: 0.924564
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 2000: 0.796348
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 0.782470
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.728993
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.9%
# L2 regularization(beta=0.00113) Test accuracy: 89.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 21.211224
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.0%
# Minibatch loss at step 500: 2.469869
# Minibatch accuracy: 84.4%
# Validation accuracy: 76.2%
# Minibatch loss at step 1000: 1.586682
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 1500: 0.832801
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 2000: 0.686326
# Minibatch accuracy: 89.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 2500: 0.778964
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.726043
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.0%
# L2 regularization(beta=0.00144) Test accuracy: 89.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 22.418909
# Minibatch accuracy: 10.2%
# Validation accuracy: 12.5%
# Minibatch loss at step 500: 2.474905
# Minibatch accuracy: 83.6%
# Validation accuracy: 76.8%
# Minibatch loss at step 1000: 1.430535
# Minibatch accuracy: 80.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 1500: 0.724905
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.9%
# Minibatch loss at step 2000: 0.659951
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.5%
# Minibatch loss at step 2500: 0.724730
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.708402
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.0%
# L2 regularization(beta=0.00183) Test accuracy: 89.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 25.870405
# Minibatch accuracy: 9.4%
# Validation accuracy: 13.0%
# Minibatch loss at step 500: 2.530553
# Minibatch accuracy: 83.6%
# Validation accuracy: 77.2%
# Minibatch loss at step 1000: 1.250924
# Minibatch accuracy: 82.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 1500: 0.612727
# Minibatch accuracy: 86.7%
# Validation accuracy: 81.3%
# Minibatch loss at step 2000: 0.617085
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.5%
# Minibatch loss at step 2500: 0.708463
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.709674
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.9%
# L2 regularization(beta=0.00234) Test accuracy: 89.0%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 24.642334
# Minibatch accuracy: 9.4%
# Validation accuracy: 14.9%
# Minibatch loss at step 500: 2.112793
# Minibatch accuracy: 84.4%
# Validation accuracy: 77.6%
# Minibatch loss at step 1000: 1.102867
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.8%
# Minibatch loss at step 1500: 0.564805
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.4%
# Minibatch loss at step 2000: 0.597127
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.6%
# Minibatch loss at step 2500: 0.712120
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.8%
# Minibatch loss at step 3000: 0.714954
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.8%
# L2 regularization(beta=0.00298) Test accuracy: 89.1%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 28.061445
# Minibatch accuracy: 11.7%
# Validation accuracy: 16.4%
# Minibatch loss at step 500: 2.002138
# Minibatch accuracy: 83.6%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 0.879389
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 1500: 0.531014
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.5%
# Minibatch loss at step 2000: 0.593740
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.7%
# Minibatch loss at step 2500: 0.721161
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.7%
# Minibatch loss at step 3000: 0.725801
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.7%
# L2 regularization(beta=0.00379) Test accuracy: 88.9%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 32.003147
# Minibatch accuracy: 9.4%
# Validation accuracy: 12.1%
# Minibatch loss at step 500: 1.567923
# Minibatch accuracy: 82.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 1000: 0.814440
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 1500: 0.531247
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 2000: 0.602295
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.5%
# Minibatch loss at step 2500: 0.731476
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.5%
# Minibatch loss at step 3000: 0.737522
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.6%
# L2 regularization(beta=0.00483) Test accuracy: 88.9%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 37.481422
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.2%
# Minibatch loss at step 500: 1.230791
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 1000: 0.772762
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 1500: 0.538119
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 2000: 0.614612
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.4%
# Minibatch loss at step 2500: 0.743761
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.3%
# Minibatch loss at step 3000: 0.750818
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.5%
# L2 regularization(beta=0.00616) Test accuracy: 88.8%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 38.322647
# Minibatch accuracy: 11.7%
# Validation accuracy: 12.0%
# Minibatch loss at step 500: 0.919982
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.1%
# Minibatch loss at step 1000: 0.765542
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 1500: 0.551760
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 2000: 0.629296
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.3%
# Minibatch loss at step 2500: 0.757753
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.2%
# Minibatch loss at step 3000: 0.765810
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.5%
# L2 regularization(beta=0.00785) Test accuracy: 88.7%
# WARNING:tensorflow:From <ipython-input-8-9df7b2ea6c66>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 47.290657
# Minibatch accuracy: 11.7%
# Validation accuracy: 14.5%
# Minibatch loss at step 500: 0.744719
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 1000: 0.776661
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 1500: 0.568483
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 2000: 0.646514
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.2%
# Minibatch loss at step 2500: 0.773891
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.1%
# Minibatch loss at step 3000: 0.782823
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.4%
# L2 regularization(beta=0.01000) Test accuracy: 88.5%

# %%
print('Best beta=%f, accuracy=%.1f%%' % (beta_val[np.argmax(accuracy_val)], max(accuracy_val)))
plt.semilogx(beta_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by regularization (logistic)')
plt.show()
# Out:
# Best beta=0.002976, accuracy=89.1%

# %% [markdown]
# 可以看出当beta的值很小的时候发生了过拟合现象。然而如果beta的值过大，那么也会发生欠拟合。最佳值应该在10^-3附近。

# %% [markdown]
# 下面采用NN模型

# %%
beta_val = np.logspace(-4, -2, 20)
batch_size = 128
accuracy_val = []

hidden_size = 1024
graph = tf.Graph()
with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32,
                                      shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights1 = tf.Variable(tf.truncated_normal([image_size * image_size, hidden_size]))
  biases1 = tf.Variable(tf.zeros([hidden_size]))
  weights = tf.Variable(tf.truncated_normal([hidden_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  beta_regul = tf.placeholder(tf.float32)
    
  # Training computation.
  y1 = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  logits = tf.matmul(y1, weights) + biases
  #loss = tf.reduce_mean(
  #      tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels)) + beta_regul * tf.nn.l2_loss(weights)  
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  loss = loss + beta_regul * (tf.nn.l2_loss(weights1) + tf.nn.l2_loss(biases1) + tf.nn.l2_loss(weights) + tf.nn.l2_loss(biases))

    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  t = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(t, weights) + biases)
  t = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(t, weights) + biases)

# %%
num_steps = 3001

for beta in beta_val:
    with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        #tf.global_variables_initializer().run
        for step in range(num_steps):
            # offset 
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size), :]
            # Prepare a dictionary telling the session where to feed the minibatch.
            feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels, beta_regul: beta}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            if (step % 500 == 0):
                print("Minibatch loss at step %d: %f" % (step, l))
                print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
                print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
        print("L2 regularization(beta=%.5f) Test accuracy: %.1f%%" % (beta, accuracy(test_prediction.eval(), test_labels)))

        accuracy_val.append(accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 447.537720
# Minibatch accuracy: 9.4%
# Validation accuracy: 28.5%
# Minibatch loss at step 500: 42.269032
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 1000: 39.513084
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.0%
# Minibatch loss at step 1500: 31.666260
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 2000: 27.818312
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 2500: 27.028563
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 3000: 24.087461
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# L2 regularization(beta=0.00010) Test accuracy: 89.1%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 423.547211
# Minibatch accuracy: 4.7%
# Validation accuracy: 30.3%
# Minibatch loss at step 500: 62.978321
# Minibatch accuracy: 80.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 44.876526
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.8%
# Minibatch loss at step 1500: 40.434677
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 2000: 31.799440
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.6%
# Minibatch loss at step 2500: 32.148579
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.1%
# Minibatch loss at step 3000: 27.729437
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.0%
# L2 regularization(beta=0.00013) Test accuracy: 90.0%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 321.680145
# Minibatch accuracy: 16.4%
# Validation accuracy: 35.0%
# Minibatch loss at step 500: 61.232948
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 1000: 51.247219
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 1500: 43.503845
# Minibatch accuracy: 86.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 2000: 37.494621
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.9%
# Minibatch loss at step 2500: 35.374187
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 3000: 31.626329
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.7%
# L2 regularization(beta=0.00016) Test accuracy: 89.8%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 376.553833
# Minibatch accuracy: 7.8%
# Validation accuracy: 28.5%
# Minibatch loss at step 500: 80.039017
# Minibatch accuracy: 72.7%
# Validation accuracy: 79.1%
# Minibatch loss at step 1000: 60.409950
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.2%
# Minibatch loss at step 1500: 50.157253
# Minibatch accuracy: 88.3%
# Validation accuracy: 79.9%
# Minibatch loss at step 2000: 44.003895
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 2500: 39.612354
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 3000: 34.711948
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# L2 regularization(beta=0.00021) Test accuracy: 89.6%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 425.390900
# Minibatch accuracy: 10.9%
# Validation accuracy: 29.6%
# Minibatch loss at step 500: 89.197296
# Minibatch accuracy: 82.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 1000: 71.967178
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.7%
# Minibatch loss at step 1500: 59.139408
# Minibatch accuracy: 85.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 2000: 48.681515
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 2500: 44.230213
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.6%
# Minibatch loss at step 3000: 37.108028
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.1%
# L2 regularization(beta=0.00026) Test accuracy: 90.2%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 438.373962
# Minibatch accuracy: 9.4%
# Validation accuracy: 33.5%
# Minibatch loss at step 500: 100.226746
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.8%
# Minibatch loss at step 1000: 80.561417
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 1500: 65.453957
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 2000: 53.985809
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 2500: 46.056915
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 3000: 37.804401
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.8%
# L2 regularization(beta=0.00034) Test accuracy: 90.9%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 518.828369
# Minibatch accuracy: 12.5%
# Validation accuracy: 39.5%
# Minibatch loss at step 500: 124.948181
# Minibatch accuracy: 77.3%
# Validation accuracy: 76.6%
# Minibatch loss at step 1000: 93.249214
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 1500: 71.380234
# Minibatch accuracy: 89.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 2000: 56.543743
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 2500: 45.554829
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.9%
# Minibatch loss at step 3000: 36.621101
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.0%
# L2 regularization(beta=0.00043) Test accuracy: 91.2%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 594.586121
# Minibatch accuracy: 11.7%
# Validation accuracy: 35.7%
# Minibatch loss at step 500: 147.926468
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 105.389351
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 1500: 75.149506
# Minibatch accuracy: 88.3%
# Validation accuracy: 82.0%
# Minibatch loss at step 2000: 57.146095
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 2500: 42.958153
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 3000: 32.606277
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.8%
# L2 regularization(beta=0.00055) Test accuracy: 91.5%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 546.723694
# Minibatch accuracy: 9.4%
# Validation accuracy: 29.2%
# Minibatch loss at step 500: 169.386032
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.5%
# Minibatch loss at step 1000: 110.579605
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.1%
# Minibatch loss at step 1500: 77.125656
# Minibatch accuracy: 88.3%
# Validation accuracy: 82.2%
# Minibatch loss at step 2000: 53.330307
# Minibatch accuracy: 88.3%
# Validation accuracy: 82.7%
# Minibatch loss at step 2500: 37.920929
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 3000: 26.758183
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.3%
# L2 regularization(beta=0.00070) Test accuracy: 92.3%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 626.260742
# Minibatch accuracy: 14.1%
# Validation accuracy: 34.0%
# Minibatch loss at step 500: 188.417908
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 1000: 116.128319
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 1500: 73.067635
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.6%
# Minibatch loss at step 2000: 46.263294
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.7%
# Minibatch loss at step 2500: 29.811016
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# Minibatch loss at step 3000: 19.234972
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# L2 regularization(beta=0.00089) Test accuracy: 93.0%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 688.829712
# Minibatch accuracy: 10.9%
# Validation accuracy: 24.5%
# Minibatch loss at step 500: 208.606262
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 1000: 115.999405
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.6%
# Minibatch loss at step 1500: 64.203339
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.5%
# Minibatch loss at step 2000: 36.218319
# Minibatch accuracy: 89.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2500: 20.925274
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.4%
# Minibatch loss at step 3000: 12.075287
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.3%
# L2 regularization(beta=0.00113) Test accuracy: 93.2%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 778.942078
# Minibatch accuracy: 3.9%
# Validation accuracy: 37.0%
# Minibatch loss at step 500: 227.477142
# Minibatch accuracy: 85.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 1000: 106.788979
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 1500: 51.435474
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 2000: 24.947018
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 2500: 12.414523
# Minibatch accuracy: 91.4%
# Validation accuracy: 86.2%
# Minibatch loss at step 3000: 6.332591
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# L2 regularization(beta=0.00144) Test accuracy: 93.3%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 957.412354
# Minibatch accuracy: 7.8%
# Validation accuracy: 30.7%
# Minibatch loss at step 500: 233.685928
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.9%
# Minibatch loss at step 1000: 91.041260
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.9%
# Minibatch loss at step 1500: 36.193302
# Minibatch accuracy: 89.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 2000: 14.651737
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.3%
# Minibatch loss at step 2500: 6.140432
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 3000: 2.827652
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.8%
# L2 regularization(beta=0.00183) Test accuracy: 93.2%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 1140.645142
# Minibatch accuracy: 10.2%
# Validation accuracy: 20.4%
# Minibatch loss at step 500: 230.685837
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 1000: 70.193916
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.3%
# Minibatch loss at step 1500: 21.805731
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.6%
# Minibatch loss at step 2000: 7.053677
# Minibatch accuracy: 91.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 2500: 2.578655
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.2%
# Minibatch loss at step 3000: 1.223743
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# L2 regularization(beta=0.00234) Test accuracy: 92.8%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 1251.152100
# Minibatch accuracy: 7.8%
# Validation accuracy: 35.2%
# Minibatch loss at step 500: 212.050171
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.4%
# Minibatch loss at step 1000: 47.096264
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.9%
# Minibatch loss at step 1500: 10.824013
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 2000: 2.803924
# Minibatch accuracy: 93.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 2500: 1.092485
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.8%
# Minibatch loss at step 3000: 0.733174
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.8%
# L2 regularization(beta=0.00298) Test accuracy: 92.6%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 1581.661743
# Minibatch accuracy: 10.9%
# Validation accuracy: 33.2%
# Minibatch loss at step 500: 178.205597
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.7%
# Minibatch loss at step 1000: 26.674704
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# Minibatch loss at step 1500: 4.330163
# Minibatch accuracy: 93.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 2000: 1.069919
# Minibatch accuracy: 93.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 2500: 0.688702
# Minibatch accuracy: 86.7%
# Validation accuracy: 85.0%
# Minibatch loss at step 3000: 0.647958
# Minibatch accuracy: 86.7%
# Validation accuracy: 85.4%
# L2 regularization(beta=0.00379) Test accuracy: 92.1%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 1805.485718
# Minibatch accuracy: 10.9%
# Validation accuracy: 32.6%
# Minibatch loss at step 500: 134.956268
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.2%
# Minibatch loss at step 1000: 12.403204
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 1500: 1.519924
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# Minibatch loss at step 2000: 0.618008
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 2500: 0.642050
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.7%
# Minibatch loss at step 3000: 0.656281
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.9%
# L2 regularization(beta=0.00483) Test accuracy: 91.6%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 2280.022217
# Minibatch accuracy: 10.2%
# Validation accuracy: 30.7%
# Minibatch loss at step 500: 88.136887
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 4.688773
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.5%
# Minibatch loss at step 1500: 0.711407
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.5%
# Minibatch loss at step 2000: 0.562727
# Minibatch accuracy: 91.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 2500: 0.664133
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 3000: 0.682299
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.4%
# L2 regularization(beta=0.00616) Test accuracy: 91.1%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 2801.820557
# Minibatch accuracy: 11.7%
# Validation accuracy: 37.6%
# Minibatch loss at step 500: 48.071278
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.5%
# Minibatch loss at step 1000: 1.699554
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 1500: 0.578773
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.8%
# Minibatch loss at step 2000: 0.579746
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.8%
# Minibatch loss at step 2500: 0.696400
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.7%
# Minibatch loss at step 3000: 0.718939
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.0%
# L2 regularization(beta=0.00785) Test accuracy: 90.8%
# WARNING:tensorflow:From <ipython-input-15-aed490bdd7c4>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Minibatch loss at step 0: 3421.330322
# Minibatch accuracy: 7.8%
# Validation accuracy: 27.9%
# Minibatch loss at step 500: 21.142349
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 1000: 0.928022
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 1500: 0.596689
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 2000: 0.612521
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.2%
# Minibatch loss at step 2500: 0.732869
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.1%
# Minibatch loss at step 3000: 0.756808
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.5%
# L2 regularization(beta=0.01000) Test accuracy: 90.3%

# %%
print('Best beta=%f, accuracy=%.1f%%' % (beta_val[np.argmax(accuracy_val)], max(accuracy_val)))
plt.semilogx(beta_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by regularization (logistic)')
plt.show()
# Out:
# Best beta=0.001438, accuracy=93.3%

# %% [markdown]
# 类比上面图，这张图也是类似的趋势，但是最佳的拟合情况可以达到93.3%，相对前面来说大大的提高。其中采用了两个新的技术。首先采用了含有隐含层+relu的双层神经网络，同时在第一层的时候使用了Dropout技术。

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# 这里要看看overfitting的结果。减少总体样本的数目，保持batch的大小来训练样本。这时候虽然采用了batch的方法，但是后期的训练的数据与前面使用的数据完全相同。有可能产生过拟合现象。
#
# 采用beta的值为0.001438，是上面拟合的最佳结果
#
# ---

# %%
# 采用一个正则化的值
beta = 0.001438
few_batch_size = batch_size * 5
small_train_dataset = train_dataset[:few_batch_size, :]
small_train_labels = train_labels[:few_batch_size, :]

print('Training set', small_train_dataset.shape, small_train_labels.shape)

num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        offset = (step * batch_size) % (small_train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = small_train_dataset[offset:(offset + batch_size), :]
        batch_labels = small_train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels, beta_regul: beta}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        # print some message
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(), valid_labels))
    print("Overfitting with small dataset Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Training set (640, 784) (640, 10)
# WARNING:tensorflow:From <ipython-input-18-775eca1f5d5f>:12 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 805.833984
# Minibatch accuracy: 6.2%
# Validation accuracy: 19.8%
# Minibatch loss at step 500: 219.908218
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 1000: 107.120148
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 1500: 52.179802
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.8%
# Minibatch loss at step 2000: 25.418415
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.1%
# Minibatch loss at step 2500: 12.386242
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 3000: 6.047629
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.2%
# Overfitting with small dataset Test accuracy: 85.0%

# %% [markdown]
# 可以看出模型在训练集上的拟合优度达到了100%然而测试集上的表现不佳

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# [这里说明](https://www.tensorflow.org/get_started/mnist/pros#f1) For this small convolutional network, performance is actually nearly identical with and without dropout. Dropout is often very effective at reducing overfitting, but it is most useful when training very large neural networks
#
# ---

# %%
batch_size = 128
hidden_size = 1024

graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    tf_beta = tf.placeholder(tf.float32)

    # Variables.
    W1 = tf.Variable(tf.truncated_normal([image_size * image_size, hidden_size]))
    b1 = tf.Variable(tf.zeros([hidden_size]))

    W2 = tf.Variable(tf.truncated_normal([hidden_size, num_labels]))
    b2 = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    y1 = tf.nn.relu(tf.matmul(tf_train_dataset, W1) + b1)
    y1 = tf.nn.dropout(y1, 0.5)  # Dropout
    logits = tf.matmul(y1, W2) + b2

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    loss = loss + tf_beta * (tf.nn.l2_loss(W1) + tf.nn.l2_loss(b1) + tf.nn.l2_loss(W2) + tf.nn.l2_loss(b2))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)

    y1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, W1) + b1)
    valid_logits = tf.matmul(y1_valid, W2) + b2
    valid_prediction = tf.nn.softmax(valid_logits)

    y1_test = tf.nn.relu(tf.matmul(tf_test_dataset, W1) + b1)
    test_logits = tf.matmul(y1_test, W2) + b2
    test_prediction = tf.nn.softmax(test_logits)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    #tf.initialize_all_variables().run()
    tf.global_variables_initializer().run
    for step in range(num_steps):
        # offset 
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels, beta_regul: beta}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    print("Dropout Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))

# %%
print('Best beta=%f, accuracy=%.1f%%' % (beta_val[np.argmax(accuracy_val)], max(accuracy_val)))
plt.semilogx(beta_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by regularization (logistic)')
plt.show()

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# Hi, myself and Zhen Zhou from the LISA lab at Université de Montréal trained a couple of **4 layer MLPs** with **1024-300-50** hidden neurons respectively. We divided the noisy set into 5/6 train 1/6 valid and kept the clean set for testing. We 97.1% accuracy on the test set at **412 epoch with early stopping**, **linear decay of the learning rate**, **a hard constraint on the norm of the weights and tanh activation units**. We get approximately 93 on valid and 98 on train. The train set is easy to overfit (you can get 100% accuracy on train if you continue training). One could probably do better if they pursue hyper-optimization further. We used Torch 7.
#
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#
# decayed_learning_rate = learning_rate * decay_rate ^ (global_step / decay_steps)
#
# ---

# %%
learning_rate = 0.5
decay_rate = 0.8
global_step = np.arange(3000)
decay_steps = 500.

decayed_learning_rate = learning_rate * decay_rate ** (global_step / decay_steps)

plot(global_step, decayed_learning_rate)
xlabel('step')
ylabel('learning_rate')
grid()

# %%
batch_size = 128
fc1_size = 1024
fc2_size = 512
fc3_size = 128

graph = tf.Graph()
with graph.as_default():
    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32,
                                      shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    tf_beta = tf.placeholder(tf.float32)
    global_step = tf.Variable(0)  # count the number of steps taken.

    # Variables.
    # stddev is very important!!!
    W1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, fc1_size], stddev=np.sqrt(2.0 / (image_size * image_size))))
    b1 = tf.Variable(tf.zeros([fc1_size]))

    W2 = tf.Variable(tf.truncated_normal([fc1_size, fc2_size], stddev=np.sqrt(2.0 / fc1_size)))
    b2 = tf.Variable(tf.zeros([fc2_size]))

    W3 = tf.Variable(tf.truncated_normal([fc2_size, fc3_size], stddev=np.sqrt(2.0 / fc2_size)))
    b3 = tf.Variable(tf.zeros([fc3_size]))

    W4 = tf.Variable(tf.truncated_normal([fc3_size, num_labels], stddev=np.sqrt(2.0 / fc3_size)))
    b4 = tf.Variable(tf.zeros([num_labels]))

    # Training computation.
    y1 = tf.nn.relu(tf.matmul(tf_train_dataset, W1) + b1)
    y1 = tf.nn.dropout(y1, 0.5)

    y2 = tf.nn.relu(tf.matmul(y1, W2) + b2)
    y2 = tf.nn.dropout(y2, 0.5)

    y3 = tf.nn.relu(tf.matmul(y2, W3) + b3)
    y3 = tf.nn.dropout(y3, 0.5)

    logits = tf.matmul(y3, W4) + b4

    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    loss = loss + tf_beta * (tf.nn.l2_loss(W1) + tf.nn.l2_loss(b1) + tf.nn.l2_loss(W2) + tf.nn.l2_loss(b2) +
                             tf.nn.l2_loss(W3) + tf.nn.l2_loss(b3) + tf.nn.l2_loss(W4) + tf.nn.l2_loss(b4))

    # Optimizer
    learning_rate = tf.train.exponential_decay(1., global_step, 1000, 0.6, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)

    y1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, W1) + b1)
    y2_valid = tf.nn.relu(tf.matmul(y1_valid, W2) + b2)
    y3_valid = tf.nn.relu(tf.matmul(y2_valid, W3) + b3)
    valid_logits = tf.matmul(y3_valid, W4) + b4
    valid_prediction = tf.nn.softmax(valid_logits)

    y1_test = tf.nn.relu(tf.matmul(tf_test_dataset, W1) + b1)
    y2_test = tf.nn.relu(tf.matmul(y1_test, W2) + b2)
    y3_test = tf.nn.relu(tf.matmul(y2_test, W3) + b3)
    test_logits = tf.matmul(y3_test, W4) + b4
    test_prediction = tf.nn.softmax(test_logits)

# %%
# Let's run it:
num_steps = 10000

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    for step in range(num_steps):
        # Pick an offset within the training data, which has been randomized.
        # Note: we could use better randomization across epochs.
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        # Generate a minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        # Prepare a dictionary telling the session where to feed the minibatch.
        # The key of the dictionary is the placeholder node of the graph to be fed,
        # and the value is the numpy array to feed to it.
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels, tf_beta: 0.001438}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(
                valid_prediction.eval(), valid_labels))
    print("Final Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-29-2046468e0b5a>:5 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.791980
# Minibatch accuracy: 8.6%
# Validation accuracy: 18.6%
# Minibatch loss at step 500: 1.363818
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.967974
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 1500: 0.738463
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.7%
# Minibatch loss at step 2000: 0.620019
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2500: 0.639130
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 3000: 0.652855
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.2%
# Minibatch loss at step 3500: 0.681844
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 4000: 0.589561
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 4500: 0.628369
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.7%
# Minibatch loss at step 5000: 0.602484
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 5500: 0.651800
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 6000: 0.653610
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.8%
# Minibatch loss at step 6500: 0.524300
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 7000: 0.636993
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.9%
# Minibatch loss at step 7500: 0.747829
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 8000: 0.845276
# Minibatch accuracy: 80.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 8500: 0.541180
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 9000: 0.673247
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 9500: 0.655359
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.9%
# Final Test accuracy: 94.2%

# %%
print learning_rate
# Out:
#   File "<ipython-input-30-cc76082cf626>", line 1
#     print learning_rate
#                       ^
# SyntaxError: invalid syntax
