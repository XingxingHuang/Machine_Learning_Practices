# %% [markdown]
# ## 1. 整理思路
# ## 2. 检查数据

# %%
import pandas as pd
# This line tells the notebook to show plots inside of the notebook
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

iris_data = pd.read_csv('iris-data.csv')
iris_data.head(20)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# ...

# %% [markdown]
# 数据是有缺失值得，150个数据点，petal_width_cm有五个缺失值

# %%
iris_data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
sb.pairplot(iris_data.dropna(), hue='class')

# %% [markdown]
# 我们可以注意到：
# 1. 本应该有三类的，但是画出来的数据有五类，程序某处需要检查
#
# 2. 有一些异常点:  `sepal_width_cm`  for `Iris-setosa`, several `sepal_length_cm` for `Iris-versicolor`.

# %% [markdown]
# ## 3. 整理数据

# %%
iris_data.loc[iris_data['class'] == 'versicolor', 'class'] = 'Iris-versicolor'
iris_data.loc[iris_data['class'] == 'Iris-setossa', 'class'] = 'Iris-setosa'

iris_data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# 上面解决了类别错误的问题，然后我们来考虑异常点的问题。这里和tricky，有时候异常点的“异常”状态也可以作为分类的考虑，而另外的一些异常点并不携带任何信息，需要剔除。根据实际情况值得注意。

# %%
# This line drops any 'Iris-setosa' rows with a separal width less than 2.5 cm
iris_data = iris_data.loc[(iris_data['class'] != 'Iris-setosa') | (iris_data['sepal_width_cm'] >= 2.5)]
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'sepal_width_cm'].hist()

# %% [markdown]
# 检查`Iris-versicolor`在0 附近的数据可以发现，这些数据都比其它的数据低两个量级，可能是单位错误导致的，可以修改正过来

# %%
iris_data.loc[(iris_data['class'] == 'Iris-versicolor') &
              (iris_data['sepal_length_cm'] < 1.0)]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
iris_data.loc[(iris_data['class'] == 'Iris-versicolor') &
              (iris_data['sepal_length_cm'] < 1.0),
              'sepal_length_cm'] *= 100.0

iris_data.loc[iris_data['class'] == 'Iris-versicolor', 'sepal_length_cm'].hist()

# %% [markdown]
# 没有数据的5列全部都是一类，`Iris-setosa`，直接剔除他们显得不是很合适。可以将他们设置为中值。

# %%
iris_data.loc[(iris_data['sepal_length_cm'].isnull()) |
              (iris_data['sepal_width_cm'].isnull()) |
              (iris_data['petal_length_cm'].isnull()) |
              (iris_data['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
average_petal_width = iris_data.loc[iris_data['class'] == 'Iris-setosa', 'petal_width_cm'].mean()

iris_data.loc[(iris_data['class'] == 'Iris-setosa') &
              (iris_data['petal_width_cm'].isnull()),
              'petal_width_cm'] = average_petal_width

iris_data.loc[(iris_data['class'] == 'Iris-setosa') &
              (iris_data['petal_width_cm'] == average_petal_width)]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5            0.25
# 8               4.4             2.9              1.4            0.25
# 9               4.9             3.1              1.5            0.25
# 10              5.4             3.7              1.5            0.25
# 11              4.8             3.4              1.6            0.25
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %% [markdown]
# 我们可以保存数据，然后重新检查一遍。

# %%
iris_data.to_csv('iris-data-clean.csv', index=False)

iris_data_clean = pd.read_csv('iris-data-clean.csv')

# %%
sb.pairplot(iris_data_clean, hue='class')

# %% [markdown]
# 总结一下需要注意的一些点:
#
# > * Make sure your data is encoded properly
#
# > * Make sure your data falls within the expected range, and use domain knowledge whenever possible to define that expected range
#
# > * Deal with missing data in one way or another: replace it if you can or drop it
#
# > * Never tidy your data manually because that is not easily reproducible
#
# > * Use code as a record of how you tidied your data
#
# > * Plot everything you can about the data at this stage of the analysis so you can *visually* confirm everything looks correct

# %% [markdown]
# 尝试以下命令，会发生什么情况，我们可以利用assert命令来让程序运行，检查到错误的时候终止，然后提示我们

# %%
assert 1 == 2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-a810b3a4aded> in <module>()
# ----> 1 assert 1 == 2
#
# AssertionError:

# %% [markdown]
# ## 4. 分析数据
# > * How is my data distributed?
#
# > * Are there any correlations in my data?
#
# > * Are there any confounding factors that explain these correlations?

# %%
sb.pairplot(iris_data_clean, hue='class')

# %% [markdown]
# 大部分数据都是正态分布的，但是`petal`测量数据表现不寻常。这是个好消息，我们可以利用petal来区分`Iris-setosa`和其它的类别。同时发现petal的两个属性相关性很好。
#
# **violin plots** 和 [box plots](https://en.wikipedia.org/wiki/Box_plot) 可以用来画出非常有用的图，检查不同属性的分布

# %%
plt.figure(figsize=(10, 10))

for column_index, column in enumerate(iris_data_clean.columns):
    if column == 'class':
        continue
    plt.subplot(2, 2, column_index + 1)
    sb.violinplot(x='class', y=column, data=iris_data_clean)

# %% [markdown]
# ## 5. 分类模型

# %% [markdown]
# wow，终于我们开始对数据建模了。
#
# > Remember: **Bad data leads to bad models.** Always check your data first.
#
# 提取出feature和class，并将数据分成训练集和测试集。

# %%
iris_data_clean = pd.read_csv('iris-data-clean.csv')

# We're using all four measurements as inputs
# Note that scikit-learn expects each entry to be a list of values, e.g.,
# [ [val1, val2, val3],
#   [val1, val2, val3],
#   ... ]
# such that our input data set is represented as a list of lists

# We can extract the data in this format from pandas like this:
all_inputs = iris_data_clean[['sepal_length_cm', 'sepal_width_cm',
                             'petal_length_cm', 'petal_width_cm']].values

# Similarly, we can extract the classes
all_classes = iris_data_clean['class'].values

from sklearn.cross_validation import train_test_split
(training_inputs,
 testing_inputs,
 training_classes,
 testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75, random_state=1)
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# 决策树（Decision tree）在理论上非常简单。决策树每一个节点都选择Yes/No将数据分开，使得结果更接近于他的真实分类。这有点类似一个古老的游戏[Twenty Questions](https://en.wikipedia.org/wiki/Twenty_Questions)。决策树包含很多的[parameters](http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)。我们需要调整参数保证最后的结果准确，但先从基本模型开始。

# %%
from sklearn.tree import DecisionTreeClassifier

# Create the classifier
decision_tree_classifier = DecisionTreeClassifier()

# Train the classifier on the training set
decision_tree_classifier.fit(training_inputs, training_classes)

# Validate the classifier on the testing set using classification accuracy
decision_tree_classifier.score(testing_inputs, testing_classes)
# Out:
# 0.97368421052631582

# %% [markdown]
# 结果很好，不是么。但是需要重复多次，将数据分成训练集和测试集，检查训练结果。
#
# 从下面模拟结果我们看出，模型给出的预测精度范围波动很大，说明有过拟合的问题。下一步需要调整参数。

# %%
model_accuracies = []

for repetition in range(1000):
    (training_inputs,
     testing_inputs,
     training_classes,
     testing_classes) = train_test_split(all_inputs, all_classes, train_size=0.75)
    
    decision_tree_classifier = DecisionTreeClassifier()
    decision_tree_classifier.fit(training_inputs, training_classes)
    classifier_accuracy = decision_tree_classifier.score(testing_inputs, testing_classes)
    model_accuracies.append(classifier_accuracy)
    
sb.distplot(model_accuracies)

# %% [markdown]
# ## 6. Cross-validation

# %%
import numpy as np
from sklearn.cross_validation import StratifiedKFold

def plot_cv(cv, n_samples):
    masks = []
    for train, test in cv:
        mask = np.zeros(n_samples, dtype=bool)
        mask[test] = 1
        masks.append(mask)
        
    plt.figure(figsize=(15, 15))
    plt.imshow(masks, interpolation='none')
    plt.ylabel('Fold')
    plt.xlabel('Row #')

plot_cv(StratifiedKFold(all_classes, n_folds=10), len(all_classes))

# %%
#tmp = StratifiedKFold(all_classes, n_folds=10)
#for train, test in tmp: print np.shape(train),np.shape(test),test

# %%
from sklearn.cross_validation import cross_val_score

decision_tree_classifier = DecisionTreeClassifier()

# cross_val_score returns a list of the scores, which we can visualize
# to get a reasonable estimate of our classifier's performance
cv_scores = cross_val_score(decision_tree_classifier, all_inputs, all_classes, cv=10)
sb.distplot(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))

# %% [markdown]
# ## 7. 参数优化 Parameter tuning
#
# 下一步是调整参数，优化模型。 我们先尝试下将决策树深度调整为1，训练结果降到60%！可以采用**grid search**的方法寻找最佳参数

# %%
decision_tree_classifier = DecisionTreeClassifier(max_depth=1)

cv_scores = cross_val_score(decision_tree_classifier, all_inputs, all_classes, cv=10)
sb.distplot(cv_scores, kde=False)
plt.title('Average score: {}'.format(np.mean(cv_scores)))

# %% [markdown]
# 调整两个参数，树的深度和特征个数

# %%
from sklearn.grid_search import GridSearchCV

decision_tree_classifier = DecisionTreeClassifier()

parameter_grid = {'max_depth': [1, 2, 3, 4, 5],
                  'max_features': [1, 2, 3, 4]}

cross_validation = StratifiedKFold(all_classes, n_folds=10)

grid_search = GridSearchCV(decision_tree_classifier,
                           param_grid=parameter_grid,
                           cv=cross_validation)

grid_search.fit(all_inputs, all_classes)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# Best score: 0.96644295302
# Best parameters: {'max_features': 2, 'max_depth': 5}

# %%
grid_visualization = []

for grid_pair in grid_search.grid_scores_:
    grid_visualization.append(grid_pair.mean_validation_score)
    
grid_visualization = np.array(grid_visualization)
grid_visualization.shape = (5, 4)
sb.heatmap(grid_visualization, cmap='Blues')
plt.xticks(np.arange(4) + 0.5, grid_search.param_grid['max_features'])
plt.yticks(np.arange(5) + 0.5, grid_search.param_grid['max_depth'][::-1])
plt.xlabel('max_features')
plt.ylabel('max_depth')

# %%
decision_tree_classifier = DecisionTreeClassifier()

parameter_grid = {'criterion': ['gini', 'entropy'],
                  'splitter': ['best', 'random'],
                  'max_depth': [1, 2, 3, 4, 5],
                  'max_features': [1, 2, 3, 4]}

cross_validation = StratifiedKFold(all_classes, n_folds=10)

grid_search = GridSearchCV(decision_tree_classifier,
                           param_grid=parameter_grid,
                           cv=cross_validation)

grid_search.fit(all_inputs, all_classes)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Best score: 0.973154362416
# Best parameters: {'max_features': 3, 'splitter': 'best', 'criterion': 'gini', 'max_depth': 3}

# %% [markdown]
# 尝试更多的参数空间后，我们用最佳参数进行重新拟合。并且可以用[GraphViz](http://www.graphviz.org/) 进行树结构的可视化

# %%
decision_tree_classifier = grid_search.best_estimator_
decision_tree_classifier
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=3, max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
import sklearn.tree as tree
from sklearn.externals.six import StringIO

with open('iris_dtc.dot', 'w') as out_file:
    out_file = tree.export_graphviz(decision_tree_classifier, out_file=out_file)

# %%
dt_scores = cross_val_score(decision_tree_classifier, all_inputs, all_classes, cv=10)

sb.boxplot(dt_scores)
sb.stripplot(dt_scores, jitter=True, color='white')

# %% [markdown]
# ## 8. 其他模型
#
# 让我们来比较一下其他模型的结果如何？Random Forest一般比单个决策树会有更好的结果。因为决策树经常出现过拟合的问题。用sklearn我们可以用类似的代码很快的实施Random Forest的结果。

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_classifier = RandomForestClassifier()

parameter_grid = {'n_estimators': [5, 10, 25, 50],
                  'criterion': ['gini', 'entropy'],
                  'max_features': [1, 2, 3, 4],
                  'warm_start': [True, False]}

cross_validation = StratifiedKFold(all_classes, n_folds=10)

grid_search = GridSearchCV(random_forest_classifier,
                           param_grid=parameter_grid,
                           cv=cross_validation)

grid_search.fit(all_inputs, all_classes)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))

grid_search.best_estimator_
# Out:
# Best score: 0.96644295302
# Best parameters: {'max_features': 2, 'n_estimators': 50, 'criterion': 'gini', 'warm_start': False}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=2, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
random_forest_classifier = grid_search.best_estimator_

rf_df = pd.DataFrame({'accuracy': cross_val_score(random_forest_classifier, all_inputs, all_classes, cv=10),
                       'classifier': ['Random Forest'] * 10})
dt_df = pd.DataFrame({'accuracy': cross_val_score(decision_tree_classifier, all_inputs, all_classes, cv=10),
                      'classifier': ['Decision Tree'] * 10})
both_df = rf_df.append(dt_df)

sb.boxplot(x='classifier', y='accuracy', data=both_df)
sb.stripplot(x='classifier', y='accuracy', data=both_df, jitter=True, color='white')

# %% [markdown]
# 看起来他们表现都不错，并没有明显搞下之分。可能是数据只有4个feature的缘故。
#
# ## 9. Reproducibility
# **As a rule, we shouldn't place much weight on a discovery that can't be reproduced**
# 我们最后可以将用过的软件名称也附上，保证模型的可重复性。[Sebastian Raschka](http://sebastianraschka.com/) 制作一个极好的工具 [notebook tool](https://github.com/rasbt/watermark) 来完成这个工作:

# %%
#%install_ext https://raw.githubusercontent.com/rasbt/watermark/master/watermark.py
# %load_ext watermark    
# %watermark -a 'Randal S. Olson' -nmv --packages numpy,pandas,scikit-learn,matplotlib,seaborn
# Out:
# ERROR:root:Line magic function `%install_ext` not found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-60-52914d2e257d> in <module>()
#       1 get_ipython().magic(u'install_ext https://raw.githubusercontent.com/rasbt/watermark/master/watermark.py')
# ----> 2 get_ipython().magic(u'load_ext watermark')
#       3 get_ipython().magic(u"watermark -a 'Randal S. Olson' -nmv --packages numpy,pandas,scikit-learn,matplotlib,seaborn")
#
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# ...

# %% [markdown]
# 最后，可以整合上面的step 1-5 来完成一个完整的machine learning项目。
